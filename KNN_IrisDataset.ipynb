# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score 
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
X , y = load_iris(return_X_y = True)

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y, test_size = 0.4 , random_state = 29)

# %%
print(X.shape)
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (150, 4)
# (90, 4)
# (30, 4)
# (60, 4)

# %%
n_range = range(1, 15)

avg_scores = []

# Iterate over the range of n values
for n in n_range:
    # Instantiate the model with the current n
    knn = KNeighborsClassifier(n_neighbors=n)
    
    # Perform cross-validation and compute the average score
    scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
    avg_scores.append(scores.mean())

# %%
# Plotting the results
plt.plot(n_range, avg_scores)
plt.xlabel('Value of n for KNN')
plt.ylabel('Cross-Validated Accuracy')
plt.show()

# %%
# Find the n value with the highest average score
best_n = n_range[np.argmax(avg_scores)]

# %%
# Instantiate the model with the best n
best_knn = KNeighborsClassifier(n_neighbors=best_n)

# %%
# Train the model on the training set
best_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Test the model on the testing set and get the accuracy score
test_accuracy = best_knn.score(X_test, y_test)

# %%
print(test_accuracy)
# Out:
# 0.9166666666666666
